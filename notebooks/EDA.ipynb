# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/qsar_fish_toxicity.csv",sep=";", names = ["CIC0","SM1_Dz(Z)","GATS1i","NdsCH","NdssC","MLOGP","LC50[-LOG(mol/L)]"])

# %%
df.head()
# Out:
#     CIC0  SM1_Dz(Z)  GATS1i  NdsCH  NdssC  MLOGP  LC50[-LOG(mol/L)]
# 0  3.260      0.829   1.676      0      1  1.453              3.770
# 1  2.189      0.580   0.863      0      0  1.348              3.115
# 2  2.125      0.638   0.831      0      0  1.348              3.531
# 3  3.027      0.331   1.472      1      0  1.807              3.510
# 4  2.094      0.827   0.860      0      0  1.886              5.390

# %%
df.shape
# Out:
# (908, 7)

# %%
df.describe()
# Out:
#              CIC0   SM1_Dz(Z)      GATS1i       NdsCH       NdssC       MLOGP  \
# count  908.000000  908.000000  908.000000  908.000000  908.000000  908.000000
# mean     2.898129    0.628468    1.293591    0.229075    0.485683    2.109285
# std      0.756088    0.428459    0.394303    0.605335    0.861279    1.433181
# min      0.667000    0.000000    0.396000    0.000000    0.000000   -2.884000
# 25%      2.347000    0.223000    0.950750    0.000000    0.000000    1.209000
# 50%      2.934000    0.570000    1.240500    0.000000    0.000000    2.127000
# 75%      3.407000    0.892750    1.562250    0.000000    1.000000    3.105000
# max      5.926000    2.171000    2.920000    4.000000    6.000000    6.515000
#
#        LC50[-LOG(mol/L)]
# count         908.000000
# mean            4.064431
# std             1.455698
# min             0.053000
# 25%             3.151750
# 50%             3.987500
# 75%             4.907500
# max             9.612000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CIC0               908 non-null    float64
#  1   SM1_Dz(Z)          908 non-null    float64
#  2   GATS1i             908 non-null    float64
#  3   NdsCH              908 non-null    int64
#  4   NdssC              908 non-null    int64
#  5   MLOGP              908 non-null    float64
#  6   LC50[-LOG(mol/L)]  908 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 49.8 KB

# %%
sns.histplot(data=df, x="CIC0")
# Out:
# <Axes: xlabel='CIC0', ylabel='Count'>

# %%
sns.histplot(data=df, x="SM1_Dz(Z)")
# Out:
# <Axes: xlabel='SM1_Dz(Z)', ylabel='Count'>

# %%
sns.histplot(data=df, x="GATS1i")
# Out:
# <Axes: xlabel='GATS1i', ylabel='Count'>

# %%
sns.histplot(data=df, x="NdsCH")
# Out:
# <Axes: xlabel='NdsCH', ylabel='Count'>

# %%
sns.histplot(data=df, x="NdssC")
# Out:
# <Axes: xlabel='NdssC', ylabel='Count'>

# %%
sns.histplot(data=df, x="MLOGP")
# Out:
# <Axes: xlabel='MLOGP', ylabel='Count'>

# %%
sns.histplot(data=df, x="LC50[-LOG(mol/L)]")
# Out:
# <Axes: xlabel='LC50[-LOG(mol/L)]', ylabel='Count'>

# %%
df.dtypes
# Out:
# CIC0                 float64
# SM1_Dz(Z)            float64
# GATS1i               float64
# NdsCH                  int64
# NdssC                  int64
# MLOGP                float64
# LC50[-LOG(mol/L)]    float64
# dtype: object

# %%
g = sns.PairGrid(df)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot, lw=3, legend=False)

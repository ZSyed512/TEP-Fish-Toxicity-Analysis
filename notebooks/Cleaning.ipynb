# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/qsar_fish_toxicity.csv",sep=";", names = ["CIC0","SM1_Dz(Z)","GATS1i","NdsCH","NdssC","MLOGP","LC50[-LOG(mol/L)]"])

# %%
df
# Out:
#       CIC0  SM1_Dz(Z)  GATS1i  NdsCH  NdssC  MLOGP  LC50[-LOG(mol/L)]
# 0    3.260      0.829   1.676      0      1  1.453              3.770
# 1    2.189      0.580   0.863      0      0  1.348              3.115
# 2    2.125      0.638   0.831      0      0  1.348              3.531
# 3    3.027      0.331   1.472      1      0  1.807              3.510
# 4    2.094      0.827   0.860      0      0  1.886              5.390
# ..     ...        ...     ...    ...    ...    ...                ...
# 903  2.801      0.728   2.226      0      2  0.736              3.109
# 904  3.652      0.872   0.867      2      3  3.983              4.040
# 905  3.763      0.916   0.878      0      6  2.918              4.818
# 906  2.831      1.393   1.077      0      1  0.906              5.317
# 907  4.057      1.032   1.183      1      3  4.754              8.201
#
# [908 rows x 7 columns]

# %%
#Checking the dataframe for missing values
df.isna().sum()
# Out:
# CIC0                 0
# SM1_Dz(Z)            0
# GATS1i               0
# NdsCH                0
# NdssC                0
# MLOGP                0
# LC50[-LOG(mol/L)]    0
# dtype: int64

# %% [markdown]
# Since there are no missing values in this dataset, we move on to the next step of data cleaning
#
# The next step is to scale the data in order to make sure all the data points fall within the same range
#
# Before scaling the data, I need to split the dataset into features and the label, as well as splitting it into training and test sets

# %%
#Next I split the dataset into X(the features) and y(the label that we are predicting)
X = df.drop("LC50[-LOG(mol/L)]", axis = 1)
y = df[["LC50[-LOG(mol/L)]"]]

#Using train_test_split I split the datasets into test and training sets and set random_state to 42 to keep it standard
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
#I then used standard scaler to scale the data, by initializing the StandardScaler and fitting it to the training data
scaler = StandardScaler()
X[X.columns] = scaler.fit_transform(X[X.columns])
X.head()
# Out:
#        CIC0  SM1_Dz(Z)    GATS1i     NdsCH     NdssC     MLOGP
# 0  0.478873   0.468288  0.970369 -0.378635  0.597484 -0.458175
# 1 -0.938408  -0.113184 -1.092634 -0.378635 -0.564220 -0.531479
# 2 -1.023101   0.022259 -1.173835 -0.378635 -0.564220 -0.531479
# 3  0.170538  -0.694657  0.452715  1.274253 -0.564220 -0.211035
# 4 -1.064124   0.463618 -1.100247 -0.378635 -0.564220 -0.155883

# %%
#Examing the first 50 rows of the final df ready for training
X.head(50)
# Out:
#         CIC0  SM1_Dz(Z)    GATS1i     NdsCH     NdssC     MLOGP
# 0   0.478873   0.468288  0.970369 -0.378635  0.597484 -0.458175
# 1  -0.938408  -0.113184 -1.092634 -0.378635 -0.564220 -0.531479
# 2  -1.023101   0.022259 -1.173835 -0.378635 -0.564220 -0.531479
# 3   0.170538  -0.694657  0.452715  1.274253 -0.564220 -0.211035
# 4  -1.064124   0.463618 -1.100247 -0.378635 -0.564220 -0.155883
# 5   0.428587  -0.694657  2.241667 -0.378635 -0.564220 -0.979680
# 6   0.371684  -1.467618 -0.585130 -0.378635 -0.564220  0.581346
# 7   0.134809  -1.467618 -0.902320  1.274253 -0.564220  0.517816
# 8  -0.368055  -0.302338 -0.770369 -0.378635 -0.564220  0.581346
# 9  -0.084863  -1.154697 -0.871870 -0.378635 -0.564220 -0.361832
# 10 -0.652570  -1.154697 -1.143385 -0.378635 -0.564220 -0.237564
# 11 -0.225136  -0.946862 -0.864258 -0.378635 -0.564220 -0.361832
# 12 -0.510974  -0.946862 -0.925158  1.274253 -0.564220 -0.237564
# 13 -0.084863  -1.154697 -0.143602 -0.378635 -0.564220 -0.174732
# ...

# %%
# Out:
# Stored 'X' (DataFrame)
